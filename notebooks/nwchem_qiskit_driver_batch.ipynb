# %% [markdown]
# #### NWchem-Qiskit Driver Code for batch evaluation
# ##### bond distance from 1.3 to 13.7
# ##### number of virtual orbital use: 1, 4, 8, 12, 18

# %%
import os 
import sys
import yaml
import os
from qiskit_nature_qe import nwchem_driver
from qiskit_algorithms import NumPyMinimumEigensolver
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_nature.second_q.algorithms import GroundStateEigensolver
from qiskit.exceptions import QiskitError
from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import SLSQP
from qiskit.primitives import Estimator
from qiskit_nature.second_q.circuit.library import HartreeFock, UCCSD, UCC
import numpy as np
from nwchem2yaml import extract_fields
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Now fix number of virtual orbitals as 1 but change bond distance.

# %%
data_dir_nwchem = os.path.join("qe_files", "3x3_periodic", "NWChem",'1covo')
data_dir_yaml = os.path.join("qe_files", "3x3_periodic", "NWChem",'1covo_yaml')
data_files = os.listdir(data_dir_nwchem)
bond_distances = []
vqe_energies = []
total_energies = []
for data_file in data_files:
    if data_file.find('out') == -1:
        continue
    temp = data_file.split('-')
    temp1 = temp[1].split('.')
    bond_distance = float(temp1[0] +'.'+ temp1[1])
    bond_distances.append(bond_distance)
    name = temp[0] + '-' + str(bond_distance)
    
    print("========= Bond distance: {} =========".format(bond_distance))
    data_file_yaml = os.path.join(data_dir_yaml, "{}.yaml".format(name))
    data = extract_fields(os.path.join(data_dir_nwchem,data_file))
    with open(data_file_yaml, 'w') as f:
        f.write(yaml.dump(data, default_flow_style=False)) 
    driver = nwchem_driver.NWchem_Driver(data_file_yaml)
    es_problem = driver.run()
    mapper = JordanWignerMapper()
    ansatz = UCCSD(
        es_problem.num_spatial_orbitals,
        es_problem.num_particles,
        mapper,
        initial_state=HartreeFock(
            es_problem.num_spatial_orbitals,
            es_problem.num_particles,
            mapper,
        ),
    )
    vqe_solver = VQE(Estimator(), ansatz, SLSQP())
    # vqe_solver.initial_point = [0.0] * ansatz.num_parameters
    vqe_solver.initial_point = np.random.rand(ansatz.num_parameters)
    calc = GroundStateEigensolver(mapper, vqe_solver)
    res = calc.solve(es_problem)
    ground_energy = res.eigenvalues[0] + es_problem.nuclear_repulsion_energy
    vqe_energies.append(ground_energy)
    total_energies.append(driver.total_energy)
    print('> Total energy from HF (Hartree):{}'.format(driver.total_energy))
# Out:
# ========= Bond distance: 1.3 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7267359408
# ========= Bond distance: 3.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.6808280113
# ========= Bond distance: 1.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7426173191
# ========= Bond distance: 1.4 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7368766551
# ========= Bond distance: 5.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.613477788
# ========= Bond distance: 7.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.591167016
# ========= Bond distance: 1.6 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7450305255
# ========= Bond distance: 1.7 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7449201965
# ========= Bond distance: 3.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.6578284625
# ========= Bond distance: 4.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.6247943926
# ========= Bond distance: 2.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7353101142
# ========= Bond distance: 6.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.5983573432
# ========= Bond distance: 2.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7080460486
# ========= Bond distance: 4.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.6393471842
# ========= Bond distance: 8.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.591167016
# ========= Bond distance: 10.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.6247943926
# ========= Bond distance: 12.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7080460484
# ========= Bond distance: 12.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.6808280111
# ========= Bond distance: 10.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.613477788
# ========= Bond distance: 13.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7426173193
# ========= Bond distance: 13.4 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7450305255
# ========= Bond distance: 9.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.5983573432
# ========= Bond distance: 13.6 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7368766553
# ========= Bond distance: 1.9 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7395949764
# ========= Bond distance: 1.8 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7429340745
# ========= Bond distance: 11.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.6578284624
# ========= Bond distance: 13.7 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7267359413
# ========= Bond distance: 13.3 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7449201965
# ========= Bond distance: 11.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.6393471841
# ========= Bond distance: 13.2 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7429340744
# ========= Bond distance: 13.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7353101141
# ========= Bond distance: 13.1 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7395949762

# %%
total_energies = np.array(total_energies)
vqe_energies = np.array(vqe_energies)
bond_distances = np.array(bond_distances)

# %%
sorted_indices = np.argsort(bond_distances)
bond_distances = bond_distances[sorted_indices]
vqe_energies = vqe_energies[sorted_indices]
total_energies = total_energies[sorted_indices]

# %% [markdown]
# #### Here we plot data out. And the figure is almost as same as what they shown in COVO paper.

# %%
plt.plot(bond_distances, vqe_energies, label='VQE results')
plt.plot(bond_distances, total_energies, label='Total energy from HF')
plt.legend(loc=1)
plt.xlabel('Bond distance')
plt.ylabel('Energy (Hartree)')
plt.title('Energy w.r.t bond distance')
plt.show()

# %% [markdown]
# ##### Now change number of virtual orbitals as well (Not ready yet)

# %%
covos = [1, 4, 8, 12, 18]
data_covos = {}
for covo in covos:
    data_dir_nwchem = os.path.join("qe_files", "3x3_periodic", "NWChem",'{}covo'.format(covo))
    data_dir_yaml = os.path.join("qe_files", "3x3_periodic", "NWChem",'{}covo_yaml'.format(covo))
    if not os.path.exists(data_dir_yaml):
        os.makedirs(os.path.join("qe_files", "3x3_periodic", "NWChem",'{}covo_yaml'.format(covo)))
    data_files = os.listdir(data_dir_nwchem)
    bond_distances = []
    vqe_energies = []
    total_energies = []
    for data_file in data_files:
        if data_file.find('out') == -1:
            continue
        temp = data_file.split('-')
        temp1 = temp[1].split('.')
        bond_distance = float(temp1[0] +'.'+ temp1[1])
        bond_distances.append(bond_distance)
        name = temp[0] + '-' + str(bond_distance)
        
        print("========= Bond distance: {} =========".format(bond_distance))
        data_file_yaml = os.path.join(data_dir_yaml, "{}.yaml".format(name))
        data = extract_fields(os.path.join(data_dir_nwchem,data_file))
        with open(data_file_yaml, 'w') as f:
            f.write(yaml.dump(data, default_flow_style=False)) 
        driver = nwchem_driver.NWchem_Driver(data_file_yaml)
        es_problem = driver.run()
        mapper = JordanWignerMapper()
        ansatz = UCCSD(
            es_problem.num_spatial_orbitals,
            es_problem.num_particles,
            mapper,
            initial_state=HartreeFock(
                es_problem.num_spatial_orbitals,
                es_problem.num_particles,
                mapper,
            ),
        )
        vqe_solver = VQE(Estimator(), ansatz, SLSQP())
        # vqe_solver.initial_point = [0.0] * ansatz.num_parameters
        vqe_solver.initial_point = np.random.rand(ansatz.num_parameters)
        calc = GroundStateEigensolver(mapper, vqe_solver)
        res = calc.solve(es_problem)
        ground_energy = res.eigenvalues[0] + es_problem.nuclear_repulsion_energy
        vqe_energies.append(ground_energy)
        total_energies.append(driver.total_energy)
        # print('> Total energy from HF (Hartree):{}'.format(driver.total_energy))
    data_covos[covo] = np.array([bond_distances, total_energies, vqe_energies])
# Out:
# ========= Bond distance: 1.3 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 3.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.4 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 5.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 7.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.6 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.7 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 3.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 4.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 2.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 6.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 2.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 4.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 8.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 10.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 12.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 12.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 10.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.4 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 9.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.6 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.9 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.8 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 11.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.7 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.3 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 11.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.2 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.1 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.3 =========
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 27
#      25     f.write(yaml.dump(data, default_flow_style=False))
#      26 driver = nwchem_driver.NWchem_Driver(data_file_yaml)
# ---> 27 es_problem = driver.run()
#      28 mapper = JordanWignerMapper()
#      29 ansatz = UCCSD(
#      30     es_problem.num_spatial_orbitals,
#      31     es_problem.num_particles,
#    (...)
#      37     ),
#      38 )
#
# File ~/Develop/Qiskit-Quantum-Espresso-Driver/qiskit_nature_qe/nwchem_driver.py:33, in NWchem_Driver.run(self)
#      32 def run(self=True) -> ElectronicStructureProblem:
# ---> 33     return self.to_problem()
#
# File ~/Develop/Qiskit-Quantum-Espresso-Driver/qiskit_nature_qe/nwchem_driver.py:40, in NWchem_Driver.to_problem(self, basis, include_dipole)
#      35 def to_problem(
#      36     self,
#      37     basis: ElectronicBasis = ElectronicBasis.MO,
#      38     include_dipole: bool = False,
#      39 ) -> ElectronicStructureProblem:
# ---> 40     problem = self.to_qiskit_problem_old()
#      41     return problem
#
# File ~/Develop/Qiskit-Quantum-Espresso-Driver/qiskit_nature_qe/nwchem_driver.py:136, in NWchem_Driver.to_qiskit_problem_old(self)
#     135 def to_qiskit_problem_old(self):
# --> 136     num_particles, n_spatial_orbitals, nucl_repulsion, h1, h2 = self.load_from_yaml(self.nwchem_output)
#     138     num_particles = (
#     139         1,
#     140         1
#     141      )   # number of electron
#     142     h_ij_up = h1[:n_spatial_orbitals,:n_spatial_orbitals]
#
# File ~/Develop/Qiskit-Quantum-Espresso-Driver/qiskit_nature_qe/nwchem_driver.py:116, in NWchem_Driver.load_from_yaml(self, file_name)
#     113 one_electron_import = data['integral_sets'][0]['hamiltonian']['one_electron_integrals']['values']
#     114 two_electron_import = data['integral_sets'][0]['hamiltonian']['two_electron_integrals']['values']
# --> 116 one_electron_spatial_integrals, two_electron_spatial_integrals = self.get_spatial_integrals(one_electron_import,two_electron_import,n_spatial_orbitals)
#     117 h1, h2 = self.convert_to_spin_index(one_electron_spatial_integrals,two_electron_spatial_integrals,n_spatial_orbitals)
#     118 # reference_energy = data['integral_sets'][0]['initial_state_suggestions'][0]['state']['energy']['value']
#
# File ~/Develop/Qiskit-Quantum-Espresso-Driver/qiskit_nature_qe/nwchem_driver.py:52, in NWchem_Driver.get_spatial_integrals(self, one_electron, two_electron, n_orb)
#      50 i = int(val[0] - 1)
#      51 j = int(val[1] - 1)
# ---> 52 one_electron_spatial_integrals[i, j] = val[2]
#      53 if i != j:
#      54     one_electron_spatial_integrals[j, i] = val[2]
#
# IndexError: index 2 is out of bounds for axis 0 with size 2
