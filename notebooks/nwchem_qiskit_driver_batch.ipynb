# %% [markdown]
# #### NWchem-Qiskit Driver Code for batch evaluation
# ##### bond distance from 1.3 to 13.7
# ##### number of virtual orbital use: 1, 4, 8, 12, 18

# %%
import os 
import sys
import yaml
import os
from qiskit_nwchem_driver import nwchem_driver
from qiskit_algorithms import NumPyMinimumEigensolver
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_nature.second_q.algorithms import GroundStateEigensolver
from qiskit.exceptions import QiskitError
from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import SLSQP
from qiskit.primitives import Estimator
from qiskit_nature.second_q.circuit.library import HartreeFock, UCCSD, UCC
import numpy as np
from qiskit_nwchem_driver.nwchem2yaml import extract_fields
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Now fix number of virtual orbitals as 1 but change bond distance.

# %%
data_dir_nwchem = os.path.join("..","data","PW_LiH_data", "3x3_periodic", "NWChem",'1covo')
data_dir_yaml = os.path.join(data_dir_nwchem)
data_files = os.listdir(data_dir_nwchem)
bond_distances = []
vqe_energies = []
total_energies = []
for data_file in data_files:
    if data_file.find('out') == -1:
        continue
    temp = data_file.split('-')
    temp1 = temp[1].split('.')
    bond_distance = float(temp1[0] +'.'+ temp1[1])
    bond_distances.append(bond_distance)
    name = temp[0] + '-' + str(bond_distance)
    
    print("========= Bond distance: {} =========".format(bond_distance))
    data_file_yaml = os.path.join(data_dir_yaml, "{}.yaml".format(name))
    data = extract_fields(os.path.join(data_dir_nwchem,data_file))
    with open(data_file_yaml, 'w') as f:
        f.write(yaml.dump(data, default_flow_style=False)) 
    driver = nwchem_driver.NWchem_Driver(data_file_yaml)
    es_problem = driver.run()
    mapper = JordanWignerMapper()
    ansatz = UCCSD(
        es_problem.num_spatial_orbitals,
        es_problem.num_particles,
        mapper,
        initial_state=HartreeFock(
            es_problem.num_spatial_orbitals,
            es_problem.num_particles,
            mapper,
        ),
    )
    vqe_solver = VQE(Estimator(), ansatz, SLSQP())
    # vqe_solver.initial_point = [0.0] * ansatz.num_parameters
    vqe_solver.initial_point = np.random.rand(ansatz.num_parameters)
    calc = GroundStateEigensolver(mapper, vqe_solver)
    res = calc.solve(es_problem)
    ground_energy = res.eigenvalues[0] + es_problem.nuclear_repulsion_energy
    vqe_energies.append(ground_energy)
    total_energies.append(driver.total_energy)
    print('> Total energy from HF (Hartree):{}'.format(driver.total_energy))
# Out:
# ========= Bond distance: 4.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# /tmp/ipykernel_9041/3155399303.py:34: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
#   vqe_solver = VQE(Estimator(), ansatz, SLSQP())
# > Total energy from HF (Hartree):-0.6393471842
# ========= Bond distance: 13.1 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7395949762
# ========= Bond distance: 12.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7080460484
# ========= Bond distance: 1.3 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7267359408
# ========= Bond distance: 9.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.5983573432
# ========= Bond distance: 7.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.591167016
# ========= Bond distance: 2.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7353101142
# ========= Bond distance: 1.6 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7450305255
# ========= Bond distance: 1.7 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7449201965
# ========= Bond distance: 13.2 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7429340744
# ========= Bond distance: 11.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.6393471841
# ========= Bond distance: 13.3 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7449201965
# ========= Bond distance: 13.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7353101141
# ========= Bond distance: 3.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.6808280113
# ========= Bond distance: 2.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7080460486
# ========= Bond distance: 1.9 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7395949764
# ========= Bond distance: 10.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.6247943926
# ========= Bond distance: 5.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.613477788
# ========= Bond distance: 1.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7426173191
# ========= Bond distance: 13.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7426173193
# ========= Bond distance: 13.6 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7368766553
# ========= Bond distance: 13.7 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7267359413
# ========= Bond distance: 1.4 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7368766551
# ========= Bond distance: 10.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.613477788
# ========= Bond distance: 4.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.6247943926
# ========= Bond distance: 6.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.5983573432
# ========= Bond distance: 11.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.6578284624
# ========= Bond distance: 3.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.6578284625
# ========= Bond distance: 8.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.591167016
# ========= Bond distance: 1.8 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7429340745
# ========= Bond distance: 13.4 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.7450305255
# ========= Bond distance: 12.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# > Total energy from HF (Hartree):-0.6808280111

# %%
total_energies = np.array(total_energies)
vqe_energies = np.array(vqe_energies)
bond_distances = np.array(bond_distances)

# %%
sorted_indices = np.argsort(bond_distances)
bond_distances = bond_distances[sorted_indices]
vqe_energies = vqe_energies[sorted_indices]
total_energies = total_energies[sorted_indices]

# %% [markdown]
# #### Here we plot data out. And the figure is almost as same as what they shown in COVO paper.

# %%
plt.plot(bond_distances, vqe_energies, label='VQE results')
plt.plot(bond_distances, total_energies, label='Total energy from HF')
plt.legend(loc=1)
plt.xlabel('Bond distance')
plt.ylabel('Energy (Hartree)')
plt.title('Energy w.r.t bond distance')
plt.show()

# %% [markdown]
# ##### Now change number of virtual orbitals as well (Not ready yet)

# %%
covos = [1, 4]
data_covos = {}
for covo in covos:
    data_dir_nwchem = os.path.join("..","data","PW_LiH_data", "3x3_periodic", "NWChem",'{}covo'.format(covo))
    data_dir_yaml = os.path.join("..","data","PW_LiH_data", "3x3_periodic", "NWChem",'{}covo_yaml'.format(covo))
    if not os.path.exists(data_dir_yaml):
        os.makedirs(os.path.join("..","data","PW_LiH_data", "3x3_periodic", "NWChem",'{}covo_yaml'.format(covo)))
    data_files = os.listdir(data_dir_nwchem)
    bond_distances = []
    vqe_energies = []
    total_energies = []
    for data_file in data_files:
        if data_file.find('out') == -1:
            continue
        temp = data_file.split('-')
        temp1 = temp[1].split('.')
        bond_distance = float(temp1[0] +'.'+ temp1[1])
        bond_distances.append(bond_distance)
        name = temp[0] + '-' + str(bond_distance)
        
        print("========= Bond distance: {} =========".format(bond_distance))
        data_file_yaml = os.path.join(data_dir_yaml, "{}.yaml".format(name))
        data = extract_fields(os.path.join(data_dir_nwchem,data_file))
        with open(data_file_yaml, 'w') as f:
            f.write(yaml.dump(data, default_flow_style=False)) 
        driver = nwchem_driver.NWchem_Driver(data_file_yaml)
        es_problem = driver.run()
        mapper = JordanWignerMapper()
        ansatz = UCCSD(
            es_problem.num_spatial_orbitals,
            es_problem.num_particles,
            mapper,
            initial_state=HartreeFock(
                es_problem.num_spatial_orbitals,
                es_problem.num_particles,
                mapper,
            ),
        )
        vqe_solver = VQE(Estimator(), ansatz, SLSQP())
        # vqe_solver.initial_point = [0.0] * ansatz.num_parameters
        vqe_solver.initial_point = np.random.rand(ansatz.num_parameters)
        calc = GroundStateEigensolver(mapper, vqe_solver)
        res = calc.solve(es_problem)
        ground_energy = res.eigenvalues[0] + es_problem.nuclear_repulsion_energy
        vqe_energies.append(ground_energy)
        total_energies.append(driver.total_energy)
        # print('> Total energy from HF (Hartree):{}'.format(driver.total_energy))
    data_covos[covo] = np.array([bond_distances, total_energies, vqe_energies])
# Out:
# ========= Bond distance: 4.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# /tmp/ipykernel_597/1885380735.py:39: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
#   vqe_solver = VQE(Estimator(), ansatz, SLSQP())
# ========= Bond distance: 13.1 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 12.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.3 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 9.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 7.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 2.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.6 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.7 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.2 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 11.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.3 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 3.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 2.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.9 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 10.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 5.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.6 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.7 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.4 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 10.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 4.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 6.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 11.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 3.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 8.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.8 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.4 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 12.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 4.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.1 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 12.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.3 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 9.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 7.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 2.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.6 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.7 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.2 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 11.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.3 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 3.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 2.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.9 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 10.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 5.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.6 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.7 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.4 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 10.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 4.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 6.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 11.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 3.5 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 8.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 1.8 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 13.4 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True
# ========= Bond distance: 12.0 =========
# h_ij up-down equal: True
# eri up-down equal: True
# eri up-(down-up) equal: False
# eri (up-down)-(down-up) equal: True

# %%
print(data_covos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(data_covos)
#
# NameError: name 'data_covos' is not defined

# %%
# Out:
# 7.9999
# 7
